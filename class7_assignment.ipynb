# %%
task:
scenario1:credit card offer

# %%
if salary < 10000---> credit limit = 10*salary
if salary 10000 to 30000---> credit limit = 20*salary
if salary > 30000----> credit limit = 30*salary

# %%
def credit_card_offer(salary):
    # credit_card_offer="credit_card"
    #salary=int(input("Enter your salary: " ) )
    if salary < 10000:
        print("your salary:",salary)
        credit_limit = salary * 10
        print("your credit card limit:",credit_limit)
    elif salary >=10000 and salary <=30000:
        print("your salary:",salary)
        credit_limit = salary * 20
        print("your credit card limit:",credit_limit) 
    else:
        credit_limit = salary * 30
        print("your salary:",salary)
        print("your credit card limit:",credit_limit)

# %%
 credit_card_offer(8000)
# Out:
# your salary: 8000
# your credit card limit: 80000

# %%
 credit_card_offer(25000)
# Out:
# your salary: 25000
# your credit card limit: 500000

# %%
credit_card_offer(40000)
# Out:
# your salary: 40000
# your credit card limit: 1200000

# %%
scenario2:

# %%
# Dmart discount offer.

# %%
pamount < 20000---pamount dis 20%
pamount >=20000 to <=40000---pamount dis 30%
pamount > 50000 pamount dis 40%

# %%
def--function
conditions---if elif elif
function call

# %%
total---pamount---discount---final bill

# %%
input
logic
output

# %%
def mart_app(mart_type,pamount):
    #(mart_type="Dmart"
    #pamount=int(input("enter your purchase amount:"))
    print("your mart is",mart_type)
    if pamount<20000:
         print("your purchase amount is",pamount)
         dis_amt=pamount*.20
         final_dis_amount=pamount-dis_amt
         print("your final payble amount is",final_dis_amount)
    elif (pamount>=20000 and pamount<=40000):
        print("your purchase amount is",pamount)
        dis_amt=pamount*.30
        final_dis_amount=pamount-dis_amt
        print("your final payble amount is",final_dis_amount)
    elif pamount>50000:
         print("your purchase amount is",pamount)
         dis_amt=pamount*.40
         final_dis_amount=pamount-dis_amt
         print("your final payble amount is",final_dis_amount)

# %%
 mart_app("Dmart",18000)
# Out:
# your mart is Dmart
# your purchase amount is 18000
# your final payble amount is 14400.0

# %%
mart_app("Dmart",25000)
# Out:
# your mart is Dmart
# your purchase amount is 25000
# your final payble amount is 17500.0

# %%
mart_app("Dmart",60000)
# Out:
# your mart is Dmart
# your purchase amount is 60000
# your final payble amount is 36000.0

# %%
#scenario3:Amazon online offer.

# %%
amazon online app
product
electronic---20%
cloth----30%
footware---40%
product dis price
total blc price

# %%
function---amazon offer
parameters---product,price

# %%
condition---if elif else

# %%
def amazon_offer(product,price):
     #product=input("enter product type(electronic/cloth/footware):")
    #price=float(input(""enter product price:"))
    if product == "electronic":
        print(" your product type is",product)
        print("your discount is 20%")
        product_dis=price*.20
        final_amount=price-product_dis
        print("your final amount is:",final_amount)
    elif product=="cloth":
        print(" your product type is",product)
        print("your discount is 30%")
        product_dis=price*.30
        final_amount=price-product_dis
        print("your final amount is:",final_amount)
    elif product == "footwear":
        print(" your product type is",product)
        print("your discount is 40%")
        product_dis=price*.40
        final_amount=price-product_dis
        print("your final amount is:",final_amount)
    else:
        print("no offer available")

# %%
amazon_offer("electronic",1000)
# Out:
#  your product type is electronic
# your discount is 20%
# your final amount is: 800.0

# %%
amazon_offer("cloth",1000)
# Out:
#  your product type is cloth
# your discount is 30%
# your final amount is: 700.0

# %%
amazon_offer("footwear",1000)
# Out:
#  your product type is footwear
# your discount is 40%
# your final amount is: 600.0

# %%
amazon_offer("food",1000)
# Out:
# no offer available
