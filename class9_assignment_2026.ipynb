# %%
#task:

# %%
#1.create a friends names.csv file (delimiter:,)

# %%
import pandas as pd

# %%
#read_csv()

# %%
#read_csv("path",header=,sep=)

# %%
df_csv=pd.read_csv(r"C:\Users\hp\salomi\friend_names.csv file.txt",sep=",")

# %%
df_csv
# Out:
#   friendname      quality
# 0   maneesha     creative
# 1     sujana         kind
# 2     pushpa        funny
# 3   Priyanka        smart
# 4    eliazer  hardworking
# 5    esterbi        loyal
# 6     Vijaya       caring
# 7    Prakash      helpful
# 8       vani       honest
# 9   bhargavi     friendly

# %%
df_csv.shape
# Out:
# (10, 2)

# %%
df_csv.columns
# Out:
# Index(['friendname', 'quality'], dtype='object')

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   friendname  10 non-null     object
#  1   quality     10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df_csv.describe()
# Out:
#        friendname   quality
# count          10        10
# unique         10        10
# top      maneesha  creative
# freq            1         1

# %%
df_csv.head()
# Out:
#   friendname      quality
# 0   maneesha     creative
# 1     sujana         kind
# 2     pushpa        funny
# 3   Priyanka        smart
# 4    eliazer  hardworking

# %%
#2.create afamily_members.txt file

# %%
df_csv=pd.read_csv(r"C:\Users\hp\salomi\family_members.txt file.txt",sep="*")

# %%
df_csv
# Out:
#    familymembername          relation
# 0          jayapaul            father
# 1     rangasarojini            mother
# 2        rajakumari      eldestsister
# 3  venkataramanayya   bigbrotherinlaw
# 4            mahima             niece
# 5         sunilraju           brother
# 6           meghana     sister_in_law
# 7       yonafrancis            nephew
# 8          sowjanya      middlesister
# 9         anilkumar      brotherinlaw

# %%
df_csv.shape
# Out:
# (10, 2)

# %%
df_csv.columns
# Out:
# Index(['familymembername', 'relation'], dtype='object')

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   familymembername  10 non-null     object
#  1   relation          10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df_csv.describe()
# Out:
#        familymembername relation
# count                10       10
# unique               10       10
# top            jayapaul   father
# freq                  1        1

# %%
#3.crate a vegfood_items.txt file (delimiter:|)

# %%
df=pd.read_csv(r"C:\Users\hp\salomi\vegfood_names.psv file.txt",sep="|")

# %%
df
# Out:
#             vegfoodname     taste
# 0  paneer butter masala     spicy
# 1             dal tadka    savory
# 2          palak paneer      mild
# 3             aloo gobi     spicy
# 4           masala dosa     tangy
# 5     vegetable biryani  fragrant
# 6         chole bhature     spicy
# 7          Malaki kofta     sweet
# 8       gobi manchurian     spicy
# 9       mixed veg curry    savory

# %%
df.shape
# Out:
# (10, 2)

# %%
df.columns
# Out:
# Index(['vegfoodname', 'taste'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vegfoodname  10 non-null     object
#  1   taste        10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#                  vegfoodname  taste
# count                     10     10
# unique                    10      6
# top     paneer butter masala  spicy
# freq                       1      4

# %%
#4.create a nonvegfood_items.txt file (delimiter:|)

# %%
df=pd.read_csv(r"C:\Users\hp\salomi\nonvegfood_items.txt file.txt",sep="|")

# %%
df
# Out:
#      nonvegfoodname    taste
# 0   chicken biryani    spicy
# 1          fish fry   crispy
# 2      mutton curry     rich
# 3    butter chicken   creamy
# 4         egg roast    tangy
# 5      prawn masala   savory
# 6      grilled fish    smoky
# 7        chicken 65      hot
# 8       keema matar    spicy
# 9  tandoori chicken  charred

# %%
df.shape
# Out:
# (10, 2)

# %%
df.columns
# Out:
# Index(['nonvegfoodname', 'taste'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nonvegfoodname  10 non-null     object
#  1   taste           10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#          nonvegfoodname  taste
# count                10     10
# unique               10      9
# top     chicken biryani  spicy
# freq                  1      2

# %%
#5.create a month_names.txt file (delimiter:&)

# %%
df=pd.read_csv(r"C:\Users\hp\salomi\month_names.txt file.txt",sep="&")

# %%
df
# Out:
#    monthname      season
# 0    january      winter
# 1   february      winter
# 2      march      spring
# 3      april      spring
# 4        may      summer
# 5       june      summer
# 6       july     monsoon
# 7     august     monsoon
# 8   septmber      autumn
# 9    October      autumn
# 10  november  pre-winter
# 11  december      winter

# %%
df.shape
# Out:
# (12, 2)

# %%
df.columns
# Out:
# Index(['monthname', 'season'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   monthname  12 non-null     object
#  1   season     12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#        monthname  season
# count         12      12
# unique        12       6
# top      january  winter
# freq           1       3

# %%
#6.colurs_names.txt file (delimiter:^)

# %%
df=pd.read_csv(r"C:\Users\hp\salomi\colours_names.txt file.txt",sep="^")

# %%
df
# Out:
#    colourname_in_english colourname_in_hindi colourname_in_telugu
# 0                    red                 lal                erupu
# 1                   blue               neela               neelam
# 2                  green                hara            akupachha
# 3                 yellow               peela               pasupu
# 4                  white               safed               telupu
# 5                  black                kala              nallapu
# 6                   pink              gulabi               gulabi
# 7                 orange             narangi              narangi
# 8                  brown               bhura              godhuma
# 9                   grey              sileti             boodidha
# 10                purple            baingani              vankaya
# 11                  gold             sunehra              bangaru

# %%
df.shape
# Out:
# (12, 3)

# %%
df.columns
# Out:
# Index(['colourname_in_english', 'colourname_in_hindi', 'colourname_in_telugu'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   colourname_in_english  12 non-null     object
#  1   colourname_in_hindi    12 non-null     object
#  2   colourname_in_telugu   12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes

# %%
df.describe()
# Out:
#        colourname_in_english colourname_in_hindi colourname_in_telugu
# count                     12                  12                   12
# unique                    12                  12                   12
# top                      red                 lal                erupu
# freq                       1                   1                    1

# %%
#7.create a friend_names.xls file

# %%
import pandas as pd

# %%
df_friends=pd.read_excel(r"C:\Users\hp\salomi\friend_names.xls file.xlsx",sheet_name="Sheet1")

# %%
df_friends
# Out:
#   FriendName      Quality
# 0   maneesha     creative
# 1     sujana         kind
# 2     pushpa        funny
# 3   priyanka        smart
# 4    eliazer  hardworking
# 5    esterbi        loyal
# 6     vijaya       caring
# 7    prakash      helpful
# 8       vani       honest
# 9       mani         calm

# %%
basic checks:

# %%
df_friends.shape
# Out:
# (10, 2)

# %%
df_friends.columns
# Out:
# Index(['FriendName', 'Quality'], dtype='object')

# %%
df_friends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FriendName  10 non-null     object
#  1   Quality     10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df_friends.describe()
# Out:
#        FriendName   Quality
# count          10        10
# unique         10        10
# top      maneesha  creative
# freq            1         1

# %%
#8.create a family_members.xls file

# %%
df_family=pd.read_excel(r"C:\Users\hp\salomi\family_members.xls file.xlsx")

# %%
df_family
# Out:
#    FamilyMemberName                Relation
# 0          jayapaul                  father
# 1     rangasarojini                  mother
# 2        rajakumari            eldestsister
# 3  venkataramanayya    elder brother_in_law
# 4            mahima                   niece
# 5         sunilraju                 brother
# 6           meghana           sister_in_law
# 7       yonafrancis                  nephew
# 8          sowjanya            middlesister
# 9         anilkumar  younger brother_in_law

# %%
df_family.shape
# Out:
# (10, 2)

# %%
df_family.columns
# Out:
# Index(['FamilyMemberName', 'Relation'], dtype='object')

# %%
df_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FamilyMemberName  10 non-null     object
#  1   Relation          10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df_family.describe()
# Out:
#        FamilyMemberName Relation
# count                10       10
# unique               10       10
# top            jayapaul   father
# freq                  1        1

# %%
#9.create a vegfood_items.xlsx file

# %%
df_veg=pd.read_excel(r"C:\Users\hp\salomi\vegfood_items.xlsx file.xlsx")

# %%
df_veg
# Out:
#             VegFoodName     Taste
# 0  paneer butter masala     spicy
# 1             dal tadka    savory
# 2          palak paneer      mild
# 3             aloo gobi     spicy
# 4           masala dosa     tangy
# 5     vegetable biryani  fragrant
# 6         chole bhature     spicy
# 7          malaki kofta     sweet
# 8       gobi manchurian     spicy
# 9       mixed veg curry    savory

# %%
df_veg.shape
# Out:
# (10, 2)

# %%
df_veg.columns
# Out:
# Index(['VegFoodName', 'Taste'], dtype='object')

# %%
df_veg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VegFoodName  10 non-null     object
#  1   Taste        10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df_veg.describe()
# Out:
#                  VegFoodName  Taste
# count                     10     10
# unique                    10      6
# top     paneer butter masala  spicy
# freq                       1      4

# %%
#10.create a nonvegfood_items.xlsx file

# %%
df_nonveg=pd.read_excel(r"C:\Users\hp\salomi\nonvegfood_items.xlsx file.xlsx")

# %%
df_nonveg
# Out:
#    NonvegFoodName      Taste
# 0   chicken curry      spicy
# 1  mutton biryani       rich
# 2        fish fry     crispy
# 3       egg curry      tasty
# 4     chicken fry      spicy
# 5          prawns      juicy
# 6           kebab      smoky
# 7   roast chicken  delicious
# 8      chicken 65        hot
# 9  butter chicken      spicy

# %%
df_nonveg.shape
# Out:
# (10, 2)

# %%
df_nonveg.columns
# Out:
# Index(['NonvegFoodName', 'Taste'], dtype='object')

# %%
df_nonveg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NonvegFoodName  10 non-null     object
#  1   Taste           10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df_nonveg.describe()
# Out:
#        NonvegFoodName  Taste
# count              10     10
# unique             10      8
# top     chicken curry  spicy
# freq                1      3

# %%
#11.create a month_names.xlsx file

# %%
df_month=pd.read_excel(r"C:\Users\hp\salomi\month_names.xlsx file.xlsx")

# %%
df_month
# Out:
#     MonthName      Season
# 0     january      winter
# 1    february      winter
# 2       march      spring
# 3       april      spring
# 4         may      summer
# 5        june      summer
# 6        july     monsoon
# 7      august     monsoon
# 8   september      autumn
# 9     october      autumn
# 10   november  pre_winter
# 11   december      winter

# %%
df_month.shape
# Out:
# (12, 2)

# %%
df_month.columns
# Out:
# Index(['MonthName', 'Season'], dtype='object')

# %%
df_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MonthName  12 non-null     object
#  1   Season     12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes

# %%
df_month.describe()
# Out:
#        MonthName  Season
# count         12      12
# unique        12       6
# top      january  winter
# freq           1       3

# %%
#12.create a colours_names.xlsx file

# %%
df_colours=pd.read_excel(r"C:\Users\hp\salomi\colours_names.xlsx file.xlsx")

# %%
df_colours
# Out:
#    colourname_in_english colourname_in_hindi colourname_in_telugu
# 0                    red                 lal                erupu
# 1                   blue               neela               neelam
# 2                  green                hara            akupachha
# 3                 yellow               peela               pasupu
# 4                  white               safed               telupu
# 5                  black                kala              nallapu
# 6                   pink              gulabi               gulabi
# 7                 orange             narangi              narangi
# 8                  brown               bhura              godhuma
# 9                   grey              sileti             boodidha
# 10                purple            baingani              vankaya
# 11                  gold             sunehra              bangaru

# %%
df_colours.shape
# Out:
# (12, 3)

# %%
df_colours.columns
# Out:
# Index(['colourname_in_english', 'colourname_in_hindi', 'colourname_in_telugu'], dtype='object')

# %%
df_colours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   colourname_in_english  12 non-null     object
#  1   colourname_in_hindi    12 non-null     object
#  2   colourname_in_telugu   12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes

# %%
df_colours.describe()
# Out:
#        colourname_in_english colourname_in_hindi colourname_in_telugu
# count                     12                  12                   12
# unique                    12                  12                   12
# top                      red                 lal                erupu
# freq                       1                   1                    1
